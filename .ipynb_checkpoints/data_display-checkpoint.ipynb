# %%
import pandas as pd

# 載入 CSV 檔案
df = pd.read_csv('data/raw/activity.csv')

# 顯示前 5 筆資料
df.head()
# Out:
#      id  trend                          title  \
# 0  6830   1012               雅緻藝術舞蹈團《今天，一起回家》
# 1  6829     73                  物品劇~《大鯨魚的小喉嚨》
# 2  6020     40  轉知：「2023 中學生跨域問題解決創意專題論壇實施計畫」
# 3  5172     24          2023 成大觀影腦影像數據分析營 第二期
# 4  6828     10                 《春風‧唯美世界》二次元古箏
#
#                                              content  subTitle  \
# 0  PGRpdiBpZD0iaG9tZV9jb250ZW50Ij4KPGRpdiBpZD0iaG...       NaN
# 1  PGRpdiBpZD0iaG9tZV9jb250ZW50Ij4KPGRpdiBpZD0iaG...       NaN
# 2  PGRpdiBjbGFzcz0iZW50cnktY29udGVudCBjbHIiIGl0ZW...       NaN
# 3  PGhlYWRlcj4KPHAgc3R5bGU9InRleHQtYWxpZ246IGNlbn...       NaN
# 4  PGRpdiBpZD0iaG9tZV9jb250ZW50Ij4KPGRpdiBpZD0iaG...       NaN
#
#                                               images connection holder  \
# 0  ['https://culture.tycg.gov.tw/./pubprogram/upl...         []     []
# 1                                                NaN         []     []
# 2                                                NaN         []     []
# ...
