# %% [markdown]
# ## 獲取活動資料

# %%
import requests
import json
import csv
import numpy as np
import pandas as pd

all_activity_df = pd.read_csv('../data/preprocess/activity.csv')

activity_df = all_activity_df.loc[all_activity_df.index <= 5]

activity_df
# Out:
#                                      id                  title  \
# 0  badfa9cc-aed2-43df-4d56-08db52fbe02a      第12屆APX全國高中數理能力檢定
# 1  4625cc40-c153-457e-4d57-08db52fbe02a             青少年帆船2日體驗營
# 2  84841d32-fec3-4f35-4d58-08db52fbe02a  2023 成大觀影腦影像數據分析營 第三期
# 3  81a759b6-6e15-465b-4d59-08db52fbe02a     2023 成大第十二期AI人才研修班
# 4  b5331379-6197-462b-4d5a-08db52fbe02a                  臺大政治營
# 5  2668c627-d2d2-4d24-4d5b-08db52fbe02a            2023中正大學勞工營
#
#                 subTitle                                            content  \
# 0      第12屆APX全國高中數理能力檢定  檢定分級級別檢定範圍及占分高級A部分，以高一到高三範圍為主，佔100分、B部分，以大學先修範...
# 1             青少年帆船2日體驗營  陽光照耀下海面波光粼粼，徜徉在千變萬化的大海裡，體驗帆船的無限魅力，帶領孩子透過體驗及實務操...
# 2  2023 成大觀影腦影像數據分析營 第三期  專業師資引導?分析演練實作招生對象全國高中生皆可以報名營隊時間2023/8/26(六)~20...
# 3     2023 成大第十二期AI人才研修班  課程期別：AI人才研修初階班(112/07/08週六–112/07/09週日)上課人數：上限...
# 4                  臺大政治營  【何謂模擬選戰】｜總統、國會選戰的精華版｜臺大政治營模擬選戰的設計理念是以「選舉」為主軸的大...
# 5            2023中正大學勞工營  中正大學是全台唯一擁有勞工系的國立大學。為了讓更多人知道勞工系，也更加了解這個系所學，並且能...
#
#    addTime                     createAt fee holders objectives  \
# 0      NaN  2023-05-12T15:16:35.3314495  []      []         []
# 1      NaN  2023-05-12T15:16:35.3350269  []      []         []
# 2      NaN  2023-05-12T15:16:35.3350899  []      []         []
# 3      NaN  2023-05-12T15:16:35.3360411  []      []         []
# 4      NaN  2023-05-12T15:16:35.3360799  []      []         []
# 5      NaN  2023-05-12T15:16:35.3360851  []      []         []
#
#                                             branches  \
# 0  [{'id': 131, 'branchName': 'General', 'locatio...
# 1  [{'id': 132, 'branchName': 'General', 'locatio...
# 2  [{'id': 133, 'branchName': 'General', 'locatio...
# 3  [{'id': 134, 'branchName': 'General', 'locatio...
# 4  [{'id': 135, 'branchName': 'General', 'locatio...
# 5  [{'id': 136, 'branchName': 'General', 'locatio...
#
#                                                 tags  \
# 0  [{'trend': 0, 'tagVoteCount': 0, 'userVoted': ...
# 1  [{'trend': 0, 'tagVoteCount': 0, 'userVoted': ...
# 2  [{'trend': 0, 'tagVoteCount': 0, 'userVoted': ...
# 3                                                 []
# 4  [{'trend': 0, 'tagVoteCount': 0, 'userVoted': ...
# 5                                                 []
#
#                                                  seg
# 0  檢定 分級 級別 檢定 範圍 占分 部分 高一 高三 範圍 為主 部分 大學 範圍 為主 中...
# 1  陽光 照耀 海面 波光 粼粼 徜徉 千變萬化 大海 體驗 帆船 無限 魅力 帶領 孩子 體驗...
# 2  專業 師資 引導 分析 演練 實作 招生 對象 高中生 報名 營隊 時間 營隊 地點 成功 ...
# 3  課程 期別 人才 研修 初階班 週六 週日 上課 人數 額滿 為止 適用 對象 高中 高職 ...
# 4  何謂 模擬 選戰 總統 國會 選戰 精華版 臺大 政治營 模擬 選戰 設計 理念 選舉 主軸...
# 5  大學 擁有 勞工系 大學 更多 知道 勞工系 了解 高中生 大學 科系 選擇 生涯 規劃 提...

# %% [markdown]
# ##   機器學習的監督學習方法來對活動進行分類，並將其標記為心理、政治、數學、理化、戶外等標籤

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC]
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
